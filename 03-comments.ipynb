# %%
# comments

# %%
# this is a comment

# %%
# comments are notes written in plain text that the interpreter completely ignores during code execution.
# Comments can be used to make the code more readable.
