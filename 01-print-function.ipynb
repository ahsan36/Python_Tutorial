# %%
# Python is Case-sensitive language
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(2.5)
# Out:
# 2.5

# %%
print(False)
# Out:
# False

# %%
print(True)
# Out:
# True

# %%
print("India", "America", "China")
# Out:
# India America China

# %%
print("India", 5, True)
# Out:
# India 5 True

# %%
print("India", "America", "China", sep='/')
# Out:
# India/America/China

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello",end = ' ')
print("World")
# Out:
# Hello World
