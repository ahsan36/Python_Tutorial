# %% [markdown]
# # Strings
# **Seq. of Chars**
#
# In Python: Unicode Chars. <br>
# Immutable. <br>
#
# **Ops:** <br>
#
# Create <br>
# Access <br>
# Add Chars <br>
# Edit <br>
# Delete <br>
# Ops on Strings <br>
# String Functions <br>

# %% [markdown]
# ## 1. Create

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
c = 'Hello'
print(c)
# Out:
# Hello

# %% [markdown]
# 'It's raining outside'

# %%
"It's raining outside"
# Out:
# "It's raining outside"

# %%
c = '''Hello''' # multi-line string
print(c)
# Out:
# Hello

# %%
c = """Hello"""
print(c)
# Out:
# Hello

# %%
c = str("Hello")
c
# Out:
# 'Hello'

# %% [markdown]
# ## 2. Access
#
# #### Accessing Substrings from a String

# %%
# Concept of indexing
c = "hello"
print(c)
# Out:
# hello

# %%
# positive indexing
print(c[0])
# Out:
# h

# %%
# negetive indexing
print(c[-1])
# Out:
# o

# %%
# Slicing

c = "Hello World"
print(c)
# Out:
# Hello World

# %%
print(c[0:5])
# Out:
# Hello

# %%
print(c[2:])
# Out:
# llo World

# %%
print(c[:4])
# Out:
# Hell

# %%
print(c[:])
# Out:
# Hello World

# %%
print(c[2:6:2])
# Out:
# lo

# %%
print(c[0:8:3])
# Out:
# HlW

# %%
print(c[0:6:-1])

# %%
print(c[-5:-1:2])
# Out:
# Wr

# %%
print(c[::-1])
# Out:
# dlroW olleH

# %%
print(c[-1:5:-1])
# Out:
# dlroW

# %% [markdown]
# ## 3. Add Chars

# %%
string1 = "Hello"
string2 = "World"

# %%
new_string = string1 + " " + string2
new_string
# Out:
# 'Hello World'

# %%
another_string = string1 + ", how are you?"
another_string
# Out:
# 'Hello, how are you?'

# %% [markdown]
# ## 4. Edit & 5. Delete

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
c[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 c[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
c = "World"
print(c)
# Out:
# World

# %%
c[5] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 c[5] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
# Deletion
c
# Out:
# 'World'

# %%
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
c = "hello"

# %%
print(c)
# Out:
# hello

# %%
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# ## 6. Ops on Strings
#
# **Arithmetic:** Concatenation (+), Repetition (*) <br>
# **Relational:** Equality (==), Inequality (!=), Comparison (<, >, <=, >=) <br>
# **Logical:** and, or, not <br>
# **Loops:** for loop, while loop <br>
# **Membership:** in, not in

# %%
# Arithmetic
"Hello" + "-" + "World"
# Out:
# 'Hello-World'

# %%
print("*"*50)
# Out:
# **************************************************

# %%
print("Hello "*4)
# Out:
# Hello Hello Hello Hello

# %%
# Relational

"Hello" == "World"
# Out:
# False

# %%
"Hello" != "World"
# Out:
# True

# %%
"Mumbai" > "Pune" # Lexiographically
# Out:
# False

# %%
"Goa" > "Kolkata"
# Out:
# False

# %%
"Mumbai" > "Mumbai"
# Out:
# False

# %%
# Logical

# "" --> False
# "Hello" --> True

# %%
"" and "Hello"
# Out:
# ''

# %%
"" or "World"
# Out:
# 'World'

# %%
"Hello" or "World"
# Out:
# 'Hello'

# %%
"Hello" and "World"
# Out:
# 'World'

# %%
not "Hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %%
# Loops on Strings

c = "Hello World"

for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for i in c[2:7]:
    print(i)
# Out:
# l
# l
# o
#
# W

# %%
for i in c[2:7:2]:
    print(i)
# Out:
# l
# o
# W

# %%
for i in c[::-1]:
    print(i)
# Out:
# d
# l
# r
# o
# W
#
# o
# l
# l
# e
# H

# %%
# Membership
c
# Out:
# 'Hello World'

# %%
'H' in c
# Out:
# True

# %%
'h' in c
# Out:
# False

# %%
'World' not in c
# Out:
# False

# %% [markdown]
# ## 7. String Functions
# ### 1. Common Functions
# len() <br>
# max() <br>
# min() <br>
# sorted()

# %%
c = 'kolkata'
len(c)
# Out:
# 7

# %%
max(c)
# Out:
# 't'

# %%
min(c)
# Out:
# 'a'

# %%
sorted(c)
# Out:
# ['a', 'a', 'k', 'k', 'l', 'o', 't']

# %%
sorted(c, reverse=True)
# Out:
# ['t', 'o', 'l', 'k', 'k', 'a', 'a']

# %% [markdown]
# ### 2. Capitalize/Title/Upper/Lower/Swapcase

# %%
c.capitalize()
# Out:
# 'Kolkata'

# %%
c
# Out:
# 'kolkata'

# %%
'it is raining today'.capitalize()
# Out:
# 'It is raining today'

# %%
'it is raining today'.title()
# Out:
# 'It Is Raining Today'

# %%
c.upper()
# Out:
# 'KOLKATA'

# %%
c.lower()
# Out:
# 'kolkata'

# %%
"KoLkAtA".swapcase()
# Out:
# 'kOlKaTa'

# %% [markdown]
# ### 3. Count

# %%
"it is raining".count("i")
# Out:
# 4

# %%
"it is raining".count("ing")
# Out:
# 1

# %%
"it is raining".count("x")
# Out:
# 0

# %% [markdown]
# ### 4. Find/Index

# %%
"it is raining".find("i")
# Out:
# 0

# %%
"it is raining".find("g")
# Out:
# 12

# %%
"it is raining".find("raining")
# Out:
# 6

# %%
"it is raining".find("x")
# Out:
# -1

# %%
"it is raining".index("raining")
# Out:
# 6

# %%
"it is raining".index("x")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 "it is raining".index("x")
#
# ValueError: substring not found

# %% [markdown]
# ### 5. endswith/startswith

# %%
"it is raining".endswith("ing")
# Out:
# True

# %%
"it is raining".endswith("ingf")
# Out:
# False

# %%
"it is raining".startswith("it")
# Out:
# True

# %% [markdown]
# ### 6. format

# %%
"Hello my name is {} and I am {}".format("Ahsan", 22)
# Out:
# 'Hello my name is Ahsan and I am 22'

# %%
"Hello my name is {1} and I am {0}".format("Ahsan", 22)
# Out:
# 'Hello my name is 22 and I am Ahsan'

# %%
"Hello my name is {name} and I am {age}".format(name = "Ahsan", age = 22)
# Out:
# 'Hello my name is Ahsan and I am 22'

# %%
"Hello my name is {age} and I am {name}".format(name = "Ahsan", age = 22)
# Out:
# 'Hello my name is 22 and I am Ahsan'

# %%
"Hello my name is {name} and I am {name}".format(name = "Ahsan", age = 22, weight = 60)
# Out:
# 'Hello my name is Ahsan and I am Ahsan'

# %% [markdown]
# ### 7. isalnum/isalpha/isdecimal/isdigit/isidentifier

# %%
"FLAT20".isalnum() # Alphanumeric
# Out:
# True

# %%
"FLAT20&".isalnum()
# Out:
# False

# %%
"FLAT".isalpha() # Alphabetic
# Out:
# True

# %%
"FLAT20".isalpha()
# Out:
# False

# %%
"20".isdigit()
# Out:
# True

# %%
"20A".isdigit()
# Out:
# False

# %%
"Hello World".isidentifier()
# Out:
# False

# %%
"Hello_World".isidentifier()
# Out:
# True

# %% [markdown]
# ### 8. Split

# %%
"who is the pm of india".split()
# Out:
# ['who', 'is', 'the', 'pm', 'of', 'india']

# %%
"who is the pm of india".split("pm")
# Out:
# ['who is the ', ' of india']

# %%
"who is the pm of india".split("i")
# Out:
# ['who ', 's the pm of ', 'nd', 'a']

# %%
"who is the pm of india".split("x")
# Out:
# ['who is the pm of india']

# %% [markdown]
# ### 9. Join

# %%
" ".join(['who', 'is', 'the', 'pm', 'of', 'india'])
# Out:
# 'who is the pm of india'

# %%
"-".join(['who', 'is', 'the', 'pm', 'of', 'india'])
# Out:
# 'who-is-the-pm-of-india'

# %% [markdown]
# ### 10. Replace

# %%
"Hi my name is A".replace("A", "B")
# Out:
# 'Hi my name is B'

# %% [markdown]
# ### 11. Strip

# %%
name = "          Saurabh           "
name
# Out:
# '          Saurabh           '

# %%
"Hi" + name
# Out:
# 'Hi          Saurabh           '

# %%
name.strip()
# Out:
# 'Saurabh'

# %%
# Length of String without len()
s = input('enter the string: ')
counter = 0
for i in s:
  counter += 1
print('length of string is', counter)
# Out:
# enter the string:  Hello
# length of string is 5
