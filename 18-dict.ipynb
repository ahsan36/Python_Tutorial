# %% [markdown]
# # Dictionary
# **Key-Value Pairs:** Data mapping. <br>
# **Aliases:** Map, associative array. <br> <br>
# dict = { 'name': 'Ahsan', 'age': 23, 'gender': 'male' }
# ### Traits:
# Mutable <br>
# No indexing <br>
# Unique keys <br>
# Immutable keys

# %%
{"Name":"Ahsan", "Gender":"Male"}
# Out:
# {'Name': 'Ahsan', 'Gender': 'Male'}

# %% [markdown]
# ## 4 Key Rules About Dictionaries
# **1.No Indexing:** No index support. <br>
# **2.Mutable:** Can modify post-creation. <br>
# **3.Keys:** Immutable (str, num, tuple); **Values:** Any type. <br>
# **4.Unique Keys:** Keys must be unique; overwrite on reassignment.

# %%
# Mutable Types   ---> Lists, Sets, Dicts

# Immutable Types ---> Str, Tuples, Int, Float, Bool, Complex

# %% [markdown]
# 1.Create <br>
# 2.Access <br>
# 3.Edit <br>
# 4.Add <br>
# 5.Delete <br>
# 6.Operations <br>
# 7.Functions

# %% [markdown]
# ### 1. Create

# %%
# empty dictionary
D = {}
D
# Out:
# {}

# %%
# 1D dictionary
D = {"Name":"Ahsan", "Gender":"Male"}
D
# Out:
# {'Name': 'Ahsan', 'Gender': 'Male'}

# %%
D1 = {[1, 2, 3]:"Ahsan"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 D1 = {[1, 2, 3]:"Ahsan"}
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
# with mixed keys
D1 = {(1, 2, 3):"Ahsan"}
D1
# Out:
# {(1, 2, 3): 'Ahsan'}

# %%
# duplicate keys
D2 = {"Name":"Abc", "Name":"Def"}
D2
# Out:
# {'Name': 'Def'}

# %%
D3 = {"Name":"Ahsan", "College":"ABC", "Marks":{"M1":99, "DS":97, "Eng":98}}
D3
# Out:
# {'Name': 'Ahsan', 'College': 'ABC', 'Marks': {'M1': 99, 'DS': 97, 'Eng': 98}}

# %%
# 2D dictionary ---> JSON
s = {
    'name':'Ahsan',
     'college':'Abc',
     'sem':4,
     'subjects':{
         'dsa':50,
         'maths':67,
         'english':34
     }
}
s
# Out:
# {'name': 'Ahsan',
#  'college': 'Abc',
#  'sem': 4,
#  'subjects': {'dsa': 50, 'maths': 67, 'english': 34}}

# %%
# mutable items as keys
D4 = {'name':'Ahsan', (1, 2, 3):2}
print(D4)
# Out:
# {'name': 'Ahsan', (1, 2, 3): 2}

# %%
# using sequence and dict function
D5 = dict([('name', 'Ahsan'), ('age', 23), (3, 3)])
D5
# Out:
# {'name': 'Ahsan', 'age': 23, 3: 3}

# %% [markdown]
# ### 2. Access

# %%
D
# Out:
# {'Name': 'Ahsan', 'Gender': 'Male'}

# %%
D[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 D[0]
#
# KeyError: 0

# %%
D["Name"]
# Out:
# 'Ahsan'

# %%
D.get("Name")
# Out:
# 'Ahsan'

# %%
D["Gender"]
# Out:
# 'Male'

# %%
D.get("Gender")
# .get() ---> 1-D dicts only; Not for 2-D/nested dicts
# Out:
# 'Male'

# %%
D3
# Out:
# {'Name': 'Ahsan', 'College': 'ABC', 'Marks': {'M1': 99, 'DS': 97, 'Eng': 98}}

# %%
D3["Marks"]["DS"]
# Out:
# 97

# %% [markdown]
# ### 3. Edit

# %%
D
# Out:
# {'Name': 'Ahsan', 'Gender': 'Male'}

# %%
D["Name"] = "ABCD"
D
# Out:
# {'Name': 'ABCD', 'Gender': 'Male'}

# %%
D3["Marks"]["DS"] = 10
D3
# Out:
# {'Name': 'Ahsan', 'College': 'ABC', 'Marks': {'M1': 99, 'DS': 10, 'Eng': 98}}

# %% [markdown]
# ### 4. Add

# %%
D
# Out:
# {'Name': 'ABCD', 'Gender': 'Male'}

# %%
D["Age"] = 22
D
# Out:
# {'Name': 'ABCD', 'Gender': 'Male', 'Age': 22}

# %%
D3["Marks"]["M2"] = 95
D3
# Out:
# {'Name': 'Ahsan',
#  'College': 'ABC',
#  'Marks': {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}}

# %% [markdown]
# ### 5. Delete

# %%
D5 = {}
D5
# Out:
# {}

# %%
del D5
D5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 del D5
# ----> 2 D5
#
# NameError: name 'D5' is not defined

# %%
D.pop('Name')
# Out:
# 'ABCD'

# %%
D.popitem()
# Out:
# ('Age', 22)

# %%
D
# Out:
# {'Gender': 'Male'}

# %%
del D["Gender"]
D
# Out:
# {}

# %%
D.clear()
D
# Out:
# {}

# %% [markdown]
# ### 6. Operations

# %%
D3
# Out:
# {'Name': 'Ahsan',
#  'College': 'ABC',
#  'Marks': {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}}

# %%
D4
# Out:
# {'name': 'Ahsan', (1, 2, 3): 2}

# %%
D3 + D4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 D3 + D4
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
D3 * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 D3 * 3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
D3
# Out:
# {'Name': 'Ahsan',
#  'College': 'ABC',
#  'Marks': {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}}

# %%
# Iteration
for i in D3:
    print(i)
# Out:
# Name
# College
# Marks

# %%
for i in D3:
    print(i, D3[i])
# Out:
# Name Ahsan
# College ABC
# Marks {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}

# %%
# Membership
"Ahsan" in  D3
# Out:
# False

# %%
"Name" in  D3
# Out:
# True

# %% [markdown]
# ### 7. Functions

# %%
len(D3)
# Out:
# 3

# %%
min(D3)
# Out:
# 'College'

# %%
max(D3)
# Out:
# 'Name'

# %%
sorted(D3)
# Out:
# ['College', 'Marks', 'Name']

# %%
sorted(D3, reverse = True)
# Out:
# ['Name', 'Marks', 'College']

# %%
D3.items()
# Out:
# dict_items([('Name', 'Ahsan'), ('College', 'ABC'), ('Marks', {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95})])

# %%
D3.keys()
# Out:
# dict_keys(['Name', 'College', 'Marks'])

# %%
D3.values()
# Out:
# dict_values(['Ahsan', 'ABC', {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}])

# %%
# update
d1 = {1:2, 3:4, 4:5}
d2 = {4:7, 6:8}
d1.update(d2)
print(d1)
# Out:
# {1: 2, 3: 4, 4: 7, 6: 8}

# %% [markdown]
# ## Dictionary Comprehension
# {key : value for var in iterable} <br>
# Creates dicts from iterables. <br>
#
# **Example:** <br><br>
#
# squares_dict = {x: x**2 for x in range(5)} <br>
#
# Maps numbers to squares. <br>
#
# Supports conditions & expressions. <br>

# %%
D = {"Name":"Ahsan", "Gender":"Male", "Age":23}

# %%
D.items()
# Out:
# dict_items([('Name', 'Ahsan'), ('Gender', 'Male'), ('Age', 23)])

# %%
D1 = {key:value for key, value in D.items() if len(key)>3}
D1
# Out:
# {'Name': 'Ahsan', 'Gender': 'Male'}

# %%
L = [1, 2, 3, 4, 5, 6, 7]

# %%
D2 = {item : item**2 for item in L}
D2
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}

# %%
D2 = {item : item**2 for item in L if item%2 == 0}
D2
# Out:
# {2: 4, 4: 16, 6: 36}

# %%
# Print 1st 10 nums & squares
{i:i**2 for i in range(1, 11)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
distances = {'delhi':1000, 'mumbai':2000, 'bangalore':3000}
print(distances.items())
# Out:
# dict_items([('delhi', 1000), ('mumbai', 2000), ('bangalore', 3000)])

# %%
# using existing dict
distances = {'delhi':1000, 'mumbai':2000, 'bangalore':3000}
{key:value*0.62 for (key, value) in distances.items()}
# Out:
# {'delhi': 620.0, 'mumbai': 1240.0, 'bangalore': 1860.0}

# %%
# using zip
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
temp_C = [30.5, 32.6, 31.8, 33.4, 29.8, 30.2, 29.9]
{i:j for (i, j) in zip(days, temp_C)}
# Out:
# {'Sunday': 30.5,
#  'Monday': 32.6,
#  'Tuesday': 31.8,
#  'Wednesday': 33.4,
#  'Thursday': 29.8,
#  'Friday': 30.2,
#  'Saturday': 29.9}

# %%
# using if condition
products = {'phone':10, 'laptop':0, 'charger':32, 'tablet':0}
{key:value for (key, value) in products.items() if value>0}
# Out:
# {'phone': 10, 'charger': 32}

# %%
# Nested Comprehension
# Print multiplication tables for 2 to 4
{i:{j:i*j for j in range(1, 11)} for i in range(2, 5)}
# Out:
# {2: {1: 2, 2: 4, 3: 6, 4: 8, 5: 10, 6: 12, 7: 14, 8: 16, 9: 18, 10: 20},
#  3: {1: 3, 2: 6, 3: 9, 4: 12, 5: 15, 6: 18, 7: 21, 8: 24, 9: 27, 10: 30},
#  4: {1: 4, 2: 8, 3: 12, 4: 16, 5: 20, 6: 24, 7: 28, 8: 32, 9: 36, 10: 40}}

# %%
{
    2:{1:2, 2:4, 3:6, 4:8},
    3:{1:3, 2:6, 3:9, 4:12},
    4:{1:4, 2:8, 3:12, 4:16}
}
# Out:
# {2: {1: 2, 2: 4, 3: 6, 4: 8},
#  3: {1: 3, 2: 6, 3: 9, 4: 12},
#  4: {1: 4, 2: 8, 3: 12, 4: 16}}
