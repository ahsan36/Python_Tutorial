# %% [markdown]
# # Literals

# %% [markdown]
# It is a raw data given in a variables.(Basic **data values** for variables.)

# %% [markdown]
# **Types:** <br>
# **1.** *Numeric literals* <br>
# **2.** *String literals* <br>
# **3.** *Boolean literals* <br>
# **4.** *Special literals* <br>

# %% [markdown]
# ### 1. Numeric literals

# %%
# Integer literals
a = 0b1010    # Binary
b = 100       # Deciaml
c = 0o310     # Octal
d = 0x12c     # Hex

# Float Literals
f1 = 10.5
f2 = 1.5e2
f3 = 1.5e-3

# Complex Literal
x = 3.14j

print(a, b, c, d)
print(f1, f2, f3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %% [markdown]
# ### 2. String literals

# %%
string = 'This is python'
strings = "This is python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is python
# This is python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %% [markdown]
# ### 3. Boolean literals

# %%
a = True + 4     # True == 1
b = False + 10   #False == 0

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %% [markdown]
# ### 4. Special literals

# %%
a = None
print(a)
# Out:
# None

# %%
# In python, We can not declare a variable, that's why we use None for declaring a variable.

# variable declaration
k = None
